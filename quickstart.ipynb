# %%
import torch
import os
import platform

# 1. Check Compute Power (GPU)
if torch.cuda.is_available():
    print(f"✅ GPU Connected: {torch.cuda.get_device_name(0)}")
else:
    print("❌ Running on CPU. Check your Colab 'Runtime Type'.")

# 2. Check Operating System (Colab is always Linux)
print(f"💻 OS: {platform.system()} ({platform.release()})")

# 3. Check Current Directory
print(f"📂 Current Folder: {os.getcwd()}")
# Out:
# ✅ GPU Connected: Tesla T4
# 💻 OS: Linux (6.6.105+)
# 📂 Current Folder: /content

# %%
import os
import sys

# Move from /content into your project folder
# Note: Ensure your local VS Code has synchronized your files to the Colab instance
project_root = "/content/sc-forecast-radar" 

if os.path.exists(project_root):
    os.chdir(project_root)
    if project_root not in sys.path:
        sys.path.append(project_root)
    print(f"✅ Switched to project root: {os.getcwd()}")
else:
    print(f"❌ Folder {project_root} not found. Check if VS Code synced your files.")
# Out:
# ❌ Folder /content/sc-forecast-radar not found. Check if VS Code synced your files.

# %%
! ls
# Out:
# sample_data

# %%
import os
print(f"I am running in: {os.getcwd()}")
print("Files visible to the GPU:")
print(os.listdir('.'))
# Out:
# I am running in: /content
# Files visible to the GPU:
# ['.config', 'sample_data']
